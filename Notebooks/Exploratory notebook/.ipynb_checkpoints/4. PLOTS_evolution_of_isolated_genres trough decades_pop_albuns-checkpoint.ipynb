# %%
import pandas as pd

# %%
df = pd.read_csv('../../Data/cleaned_data/1. rate_your_music_top_most_popular_albuns_CLEANED_decade.csv')

# %%
df
# Out:
#       popular_ranking          artist_name decade       genre
# 0                   1            radiohead   90's        rock
# 1                   2            radiohead   00's        rock
# 2                   3           pink floyd   70's        rock
# 3                   4  my bloody valentine   90's        rock
# 4                   5           kanye west   10's         pop
# ...               ...                  ...    ...         ...
# 4839             4995       blind guardian   80's       metal
# 4840             4996              eluvium   00's  electronic
# 4841             4997            summoning   00's       metal
# 4842             4999       third ear band   70's        folk
# 4843             5000                 abba   70's         pop
#
# [4844 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df
# Out:
#       popular_ranking          artist_name decade       genre
# 0                   1            radiohead   90's        rock
# 1                   2            radiohead   00's        rock
# 2                   3           pink floyd   70's        rock
# 3                   4  my bloody valentine   90's        rock
# 4                   5           kanye west   10's         pop
# ...               ...                  ...    ...         ...
# 4839             4995       blind guardian   80's       metal
# 4840             4996              eluvium   00's  electronic
# 4841             4997            summoning   00's       metal
# 4842             4999       third ear band   70's        folk
# 4843             5000                 abba   70's         pop
#
# [4844 rows x 4 columns]

# %%
import numpy as pd

df2 = df.groupby(['decade','genre']).agg({'popular_ranking': 'count'})

df2
# Out:
#                    popular_ranking
# decade genre
# 00's   blues                     1
#        country                   6
#        electronic               74
#        folk                     48
#        hip-hop                  66
#        jazz                      9
#        metal                   201
#        pop                     120
#        rock                    514
#        soul_funk                 6
# 10's   country                   3
#        electronic              177
#        folk                     49
#        hip-hop                 216
#        jazz                     32
#        metal                   120
#        pop                     334
#        reggae                    1
#        rock                    482
#        soul_funk                57
# 50's   jazz                     28
#        rock                      5
# 60's   blues                     4
#        electronic                1
#        folk                     22
# ...

# %%
#import numpy as np

#d3 = d3.iloc[np.r_[19:58,1:18], :].reset_index(drop = True )
#d3

# %%
import numpy as np
df2.reset_index()
# Out:
#    decade       genre  popular_ranking
# 0    00's       blues                1
# 1    00's     country                6
# 2    00's  electronic               74
# 3    00's        folk               48
# 4    00's     hip-hop               66
# 5    00's        jazz                9
# 6    00's       metal              201
# 7    00's         pop              120
# 8    00's        rock              514
# 9    00's   soul_funk                6
# 10   10's     country                3
# 11   10's  electronic              177
# 12   10's        folk               49
# 13   10's     hip-hop              216
# 14   10's        jazz               32
# 15   10's       metal              120
# 16   10's         pop              334
# 17   10's      reggae                1
# 18   10's        rock              482
# 19   10's   soul_funk               57
# 20   50's        jazz               28
# 21   50's        rock                5
# 22   60's       blues                4
# ...

# %%
df2 = df2.iloc[np.r_[20:56,1:19], :].reset_index()
df2
# Out:
#    decade       genre  popular_ranking
# 0    50's        jazz               28
# 1    50's        rock                5
# 2    60's       blues                4
# 3    60's  electronic                1
# 4    60's        folk               22
# 5    60's        jazz               59
# 6    60's         pop               21
# 7    60's        rock              150
# 8    60's   soul_funk                9
# 9    70's       blues                3
# 10   70's     country                1
# 11   70's  electronic               33
# 12   70's        folk               21
# 13   70's        jazz               29
# 14   70's       metal                5
# 15   70's         pop               23
# 16   70's      reggae                7
# 17   70's        rock              460
# 18   70's   soul_funk               28
# 19   80's  electronic               47
# 20   80's        folk                3
# 21   80's     hip-hop               14
# 22   80's        jazz                1
# ...

# %%
df2['genre'].value_counts()
# Out:
# jazz          7
# rock          7
# electronic    6
# folk          6
# pop           6
# metal         5
# soul_funk     4
# country       4
# hip-hop       4
# reggae        3
# blues         2
# Name: genre, dtype: int64

# %%
d4 = df2[df2['genre'] == 'rock']
d5 = df2[df2['genre'] == 'soul_funk']
d6 = df2[df2['genre'] == 'pop']
d7 = df2[df2['genre'] == 'hip-hop']
d8 = df2[df2['genre'] == 'country']
d9 = df2[df2['genre'] == 'folk']
d10 = df2[df2['genre'] == 'jazz']
d11 = df2[df2['genre'] == 'electronic']
d12 = df2[df2['genre'] == 'metal']

# %%
fig, ax = plt.subplots(figsize=(6,5))
sns.lineplot(data=d4, y='popular_ranking', x = 'decade', hue = 'genre')
plt.savefig('rock_pop_albuns.pdf')
plt.show()


fig, ax = plt.subplots(figsize=(10,5))
sns.lineplot(data=d5, y='popular_ranking', x = 'decade', hue = 'genre')
plt.show()

fig, ax = plt.subplots(figsize=(10,5))
sns.lineplot(data=d6, y='popular_ranking', x = 'decade', hue = 'genre')
plt.savefig('pop_pop_albuns.png')
plt.show()

fig, ax = plt.subplots(figsize=(10,5))
sns.lineplot(data=d7, y='popular_ranking', x = 'decade', hue = 'genre')
plt.savefig('hip_hop_pop_albuns.png')
plt.show()

fig, ax = plt.subplots(figsize=(10,5))
sns.lineplot(data=d8, y='popular_ranking', x = 'decade', hue = 'genre')
plt.show()

fig, ax = plt.subplots(figsize=(10,5))
sns.lineplot(data=d9, y='popular_ranking', x = 'decade', hue = 'genre')
plt.show()

fig, ax = plt.subplots(figsize=(10,5))
sns.lineplot(data=d10, y='popular_ranking', x = 'decade', hue = 'genre')
plt.show()

fig, ax = plt.subplots(figsize=(10,5))
sns.lineplot(data=d11, y='popular_ranking', x = 'decade', hue = 'genre')
plt.savefig('electronic_pop_albuns.png')
plt.show()

fig, ax = plt.subplots(figsize=(10,5))
sns.lineplot(data=d12, y='popular_ranking', x = 'decade', hue = 'genre')
plt.show()

# %%
import pandas as pd

most_popular_albuns_and_nominated_artists = pd.read_csv('../../Data/cleaned_data/merged_data/most_popular_albuns_and_nominated_artists.csv')

#spotify_top_hits_2000_2019 = pd.read_csv('../../Data/cleaned_data/3. Top Hits Spotify from 2000-2019[CLEANED].csv')

best_selling_artists_of_all_time = pd.read_csv('../../Data/cleaned_data/4. best_selling_artists_of_all_time[CLEANED].csv')

#spotify_most_played_songs_of_all_time = pd.read_csv('../../Data/cleaned_data/5. Spotify-2000.csv')

# %%
most_popular_albuns_and_nominated_artists
# Out:
#       popular_ranking                  artist_name  release_date genre  \
# 0                 1.0                    radiohead        1997.0  rock
# 1                 2.0                    radiohead        2000.0  rock
# 2                 6.0                    radiohead        2007.0  rock
# 3                 9.0                    radiohead        1995.0  rock
# 4                21.0                    radiohead        2001.0  rock
# ...               ...                          ...           ...   ...
# 4862              0.0                 the drifters        1960.0  soul
# 4863              0.0                 james taylor        1970.0  folk
# 4864              0.0          booker t & the mg's        1960.0  soul
# 4865              0.0  diana ross and the supremes        1970.0  soul
# 4866              0.0                 carl perkins        1950.0  rock
#
#       total_awards_nominations  uk number 1's
# 0                         18.0            0.0
# 1                         18.0            0.0
# 2                         18.0            0.0
# 3                         18.0            0.0
# 4                         18.0            0.0
# ...                        ...            ...
# 4862                       1.0            0.0
# 4863                      18.0            0.0
# 4864                       4.0            0.0
# 4865                       2.0            1.0
# 4866                       2.0            0.0
#
# [4867 rows x 6 columns]

# %%
best_selling_artists_of_all_time
# Out:
#          artist_name         country  year      genre  sales
# 0        the beatles  united kingdom  1962       Rock    600
# 1      elvis presley   united states  1956       Rock    500
# 2    michael jackson   united states  1971        Pop    400
# 3         elton john  united kingdom  1970        Pop    300
# 4              queen  united kingdom  1973       Rock    300
# ..               ...             ...   ...        ...    ...
# 116       the police  united kingdom  1978        Pop     75
# 117   gloria estefan   united states  1984  Latin pop     75
# 118    barry manilow   united states  1973        Pop     75
# 119             kiss   united states  1974       Rock     75
# 120  aretha franklin   united states  1961       Soul     75
#
# [121 rows x 5 columns]

# %%
a = most_popular_albuns_and_nominated_artists
b = best_selling_artists_of_all_time

most_popular_albuns_and_nominated_artists_with_sales = pd.merge(left = a, right = b, left_on = 'artist_name', 
                                                   right_on = 'artist_name', how = 'outer' )

most_popular_albuns_and_nominated_artists_with_sales.tail(50)
# Out:
#       popular_ranking                  artist_name  release_date genre_x  \
# 4862              0.0                 the drifters        1960.0    soul
# 4863              0.0                 james taylor        1970.0    folk
# 4864              0.0          booker t & the mg's        1960.0    soul
# 4865              0.0  diana ross and the supremes        1970.0    soul
# 4866              0.0                 carl perkins        1950.0    rock
# 4867              NaN                 mariah carey           NaN     NaN
# 4868              NaN              whitney houston           NaN     NaN
# 4869              NaN                  celine dion           NaN     NaN
# 4870              NaN                 garth brooks           NaN     NaN
# 4871              NaN             barbra streisand           NaN     NaN
# 4872              NaN                  chris brown           NaN     NaN
# 4873              NaN                     bee gees           NaN     NaN
# 4874              NaN                george strait           NaN     NaN
# 4875              NaN                         pink           NaN     NaN
# 4876              NaN                          b'z           NaN     NaN
# 4877              NaN                 shania twain           NaN     NaN
# 4878              NaN              backstreet boys           NaN     NaN
# 4879              NaN                 neil diamond           NaN     NaN
# 4880              NaN                      journey           NaN     NaN
# 4881              NaN                 kenny rogers           NaN     NaN
# 4882              NaN               julio iglesias           NaN     NaN
# 4883              NaN                    foreigner           NaN     NaN
# 4884              NaN                      chicago           NaN     NaN
# 4885              NaN               the carpenters           NaN     NaN
# 4886              NaN           earth, wind & fire           NaN     NaN
# 4887              NaN                         cher           NaN     NaN
# 4888              NaN           olivia newton-john           NaN     NaN
# 4889              NaN               linda ronstadt           NaN     NaN
# 4890              NaN                 donna summer           NaN     NaN
# 4891              NaN                  alicia keys           NaN     NaN
# 4892              NaN           christina aguilera           NaN     NaN
# 4893              NaN                lionel richie           NaN     NaN
# 4894              NaN                     flo rida           NaN     NaN
# 4895              NaN                        usher           NaN     NaN
# 4896              NaN                      shakira           NaN     NaN
# 4897              NaN                   tim mcgraw           NaN     NaN
# 4898              NaN               ayumi hamasaki           NaN     NaN
# 4899              NaN              johnny hallyday           NaN     NaN
# 4900              NaN                   luke bryan           NaN     NaN
# 4901              NaN                 tupac shakur           NaN     NaN
# 4902              NaN                      alabama           NaN     NaN
# 4903              NaN                     r. kelly           NaN     NaN
# 4904              NaN              robbie williams           NaN     NaN
# 4905              NaN                    bob seger           NaN     NaN
# 4906              NaN                      kenny g           NaN     NaN
# 4907              NaN                         enya           NaN     NaN
# 4908              NaN                  bryan adams           NaN     NaN
# 4909              NaN                   bob marley           NaN     NaN
# 4910              NaN               gloria estefan           NaN     NaN
# 4911              NaN                barry manilow           NaN     NaN
#
#       total_awards_nominations  uk number 1's         country    year  \
# 4862                       1.0            0.0             NaN     NaN
# 4863                      18.0            0.0   united states  1970.0
# 4864                       4.0            0.0             NaN     NaN
# 4865                       2.0            1.0             NaN     NaN
# 4866                       2.0            0.0             NaN     NaN
# 4867                       NaN            NaN   united states  1990.0
# 4868                       NaN            NaN   united states  1984.0
# 4869                       NaN            NaN          canada  1981.0
# 4870                       NaN            NaN   united states  1989.0
# 4871                       NaN            NaN   united states  1963.0
# 4872                       NaN            NaN   united states  2005.0
# 4873                       NaN            NaN  united kingdom  1963.0
# 4874                       NaN            NaN   united states  1984.0
# 4875                       NaN            NaN   united states  2000.0
# 4876                       NaN            NaN           japan  1988.0
# 4877                       NaN            NaN          canada  1993.0
# 4878                       NaN            NaN   united states  1995.0
# 4879                       NaN            NaN   united states  1966.0
# 4880                       NaN            NaN   united states  1975.0
# 4881                       NaN            NaN   united states  1975.0
# 4882                       NaN            NaN           spain  1968.0
# 4883                       NaN            NaN   united states  1977.0
# 4884                       NaN            NaN   united states  1969.0
# 4885                       NaN            NaN   united states  1969.0
# 4886                       NaN            NaN   united states  1971.0
# 4887                       NaN            NaN   united states  1965.0
# 4888                       NaN            NaN       australia  1966.0
# 4889                       NaN            NaN   united states  1968.0
# 4890                       NaN            NaN   united states  1974.0
# 4891                       NaN            NaN   united states  2001.0
# 4892                       NaN            NaN   united states  1998.0
# 4893                       NaN            NaN   united states  1981.0
# 4894                       NaN            NaN   united states  2007.0
# 4895                       NaN            NaN   united states  1994.0
# 4896                       NaN            NaN        colombia  1995.0
# 4897                       NaN            NaN   united states  1994.0
# 4898                       NaN            NaN           japan  1998.0
# 4899                       NaN            NaN          france  1960.0
# 4900                       NaN            NaN   united states  2007.0
# 4901                       NaN            NaN   united states  1991.0
# 4902                       NaN            NaN   united states  1980.0
# 4903                       NaN            NaN   united states  1991.0
# 4904                       NaN            NaN  united kingdom  1996.0
# 4905                       NaN            NaN   united states  1967.0
# 4906                       NaN            NaN   united states  1984.0
# 4907                       NaN            NaN         ireland  1987.0
# 4908                       NaN            NaN          canada  1979.0
# 4909                       NaN            NaN         jamaica  1975.0
# 4910                       NaN            NaN   united states  1984.0
# 4911                       NaN            NaN   united states  1973.0
#
#                genre_y  sales
# 4862               NaN    NaN
# 4863              Rock  100.0
# 4864               NaN    NaN
# 4865               NaN    NaN
# 4866               NaN    NaN
# 4867              Soul  220.0
# 4868              Soul  200.0
# 4869              Rock  200.0
# 4870           Country  170.0
# 4871               Pop  150.0
# 4872               Pop  140.0
# 4873               Pop  120.0
# 4874           Country  100.0
# 4875               Pop  100.0
# 4876              Rock  100.0
# 4877           Country  100.0
# 4878               Pop  100.0
# 4879               Pop  100.0
# 4880              Rock  100.0
# 4881           Country  100.0
# 4882         Latin pop  100.0
# 4883              Rock  100.0
# 4884              Rock  100.0
# 4885               Pop  100.0
# 4886              Soul  100.0
# 4887               Pop  100.0
# 4888               Pop  100.0
# 4889              Rock  100.0
# 4890               Pop  100.0
# 4891              Soul   90.0
# 4892              Soul  901.0
# 4893               Pop   90.0
# 4894           Hip-Hop   80.0
# 4895              Soul   80.0
# 4896         Latin pop   80.0
# 4897           Country   80.0
# 4898        Electronic   80.0
# 4899              Rock   80.0
# 4900           Country   75.0
# 4901           Hip-Hop   75.0
# 4902           Country   75.0
# 4903              Soul   75.0
# 4904               Pop   75.0
# 4905              Rock   75.0
# 4906              Jazz   75.0
# 4907  New-age / Celtic   75.0
# 4908              Rock   75.0
# 4909            Reggae   75.0
# 4910         Latin pop   75.0
# 4911               Pop   75.0

# %%
#drop columns that we'll don't need to achieve the project main goals
   
most_popular_albuns_and_nominated_artists_with_sales = most_popular_albuns_and_nominated_artists_with_sales.drop(['country'], axis = 1)

# %%
most_popular_albuns_and_nominated_artists_with_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4912 entries, 0 to 4911
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   popular_ranking           4867 non-null   float64
#  1   artist_name               4912 non-null   object
#  2   release_date              4867 non-null   float64
#  3   genre_x                   4867 non-null   object
#  4   total_awards_nominations  4867 non-null   float64
#  5   uk number 1's             4867 non-null   float64
#  6   year                      528 non-null    float64
#  7   genre_y                   528 non-null    object
#  8   sales                     528 non-null    float64
# dtypes: float64(6), object(3)
# memory usage: 383.8+ KB

# %%
d_test = most_popular_albuns_and_nominated_artists_with_sales[most_popular_albuns_and_nominated_artists_with_sales['popular_ranking'].isna() == True]
d_test.shape
# it's good to check if this artists are not included in the df most_popular_albuns so we can see if the merge went well

list1 = list(d_test['artist_name'])
most_popular_albuns_and_nominated_artists['popular_ranking'].isin(list1).value_counts() #--> all false: ok!
    # merge went's good since none of that artist is in the df 'most_popular_albuns'
    
d_test2 = most_popular_albuns_and_nominated_artists_with_sales[most_popular_albuns_and_nominated_artists_with_sales['release_date'].isna() == True]#--> all false: ok!
d_test2.shape
     # merge went's good by checking the missing values in the column release_date
    
list1 = list(d_test['artist_name'])
most_popular_albuns_and_nominated_artists['total_awards_nominations'].isin(list1).value_counts() #--> all false: ok!
    # merge went's good since none of that artist is in the df 'most_popular_albuns'
# Out:
# False    4867
# Name: total_awards_nominations, dtype: int64

# %%
# Now it is important to fill all the missing values
# For this, the approach will be to replace the existing column, that have Nan, with the information given of the columns
 # of the last merge.




most_popular_albuns_and_nominated_artists_with_sales[most_popular_albuns_and_nominated_artists_with_sales['popular_ranking'].\
                                                     isna() == True]
# Out:
#       popular_ranking         artist_name  release_date genre_x  \
# 4867              NaN        mariah carey           NaN     NaN
# 4868              NaN     whitney houston           NaN     NaN
# 4869              NaN         celine dion           NaN     NaN
# 4870              NaN        garth brooks           NaN     NaN
# 4871              NaN    barbra streisand           NaN     NaN
# 4872              NaN         chris brown           NaN     NaN
# 4873              NaN            bee gees           NaN     NaN
# 4874              NaN       george strait           NaN     NaN
# 4875              NaN                pink           NaN     NaN
# 4876              NaN                 b'z           NaN     NaN
# 4877              NaN        shania twain           NaN     NaN
# 4878              NaN     backstreet boys           NaN     NaN
# 4879              NaN        neil diamond           NaN     NaN
# 4880              NaN             journey           NaN     NaN
# 4881              NaN        kenny rogers           NaN     NaN
# 4882              NaN      julio iglesias           NaN     NaN
# 4883              NaN           foreigner           NaN     NaN
# 4884              NaN             chicago           NaN     NaN
# 4885              NaN      the carpenters           NaN     NaN
# 4886              NaN  earth, wind & fire           NaN     NaN
# 4887              NaN                cher           NaN     NaN
# 4888              NaN  olivia newton-john           NaN     NaN
# 4889              NaN      linda ronstadt           NaN     NaN
# 4890              NaN        donna summer           NaN     NaN
# 4891              NaN         alicia keys           NaN     NaN
# 4892              NaN  christina aguilera           NaN     NaN
# 4893              NaN       lionel richie           NaN     NaN
# 4894              NaN            flo rida           NaN     NaN
# 4895              NaN               usher           NaN     NaN
# 4896              NaN             shakira           NaN     NaN
# 4897              NaN          tim mcgraw           NaN     NaN
# 4898              NaN      ayumi hamasaki           NaN     NaN
# 4899              NaN     johnny hallyday           NaN     NaN
# 4900              NaN          luke bryan           NaN     NaN
# 4901              NaN        tupac shakur           NaN     NaN
# 4902              NaN             alabama           NaN     NaN
# 4903              NaN            r. kelly           NaN     NaN
# 4904              NaN     robbie williams           NaN     NaN
# 4905              NaN           bob seger           NaN     NaN
# 4906              NaN             kenny g           NaN     NaN
# 4907              NaN                enya           NaN     NaN
# 4908              NaN         bryan adams           NaN     NaN
# 4909              NaN          bob marley           NaN     NaN
# 4910              NaN      gloria estefan           NaN     NaN
# 4911              NaN       barry manilow           NaN     NaN
#
#       total_awards_nominations  uk number 1's    year           genre_y  sales
# 4867                       NaN            NaN  1990.0              Soul  220.0
# 4868                       NaN            NaN  1984.0              Soul  200.0
# 4869                       NaN            NaN  1981.0              Rock  200.0
# 4870                       NaN            NaN  1989.0           Country  170.0
# 4871                       NaN            NaN  1963.0               Pop  150.0
# 4872                       NaN            NaN  2005.0               Pop  140.0
# 4873                       NaN            NaN  1963.0               Pop  120.0
# 4874                       NaN            NaN  1984.0           Country  100.0
# 4875                       NaN            NaN  2000.0               Pop  100.0
# 4876                       NaN            NaN  1988.0              Rock  100.0
# 4877                       NaN            NaN  1993.0           Country  100.0
# 4878                       NaN            NaN  1995.0               Pop  100.0
# 4879                       NaN            NaN  1966.0               Pop  100.0
# 4880                       NaN            NaN  1975.0              Rock  100.0
# 4881                       NaN            NaN  1975.0           Country  100.0
# 4882                       NaN            NaN  1968.0         Latin pop  100.0
# 4883                       NaN            NaN  1977.0              Rock  100.0
# 4884                       NaN            NaN  1969.0              Rock  100.0
# 4885                       NaN            NaN  1969.0               Pop  100.0
# 4886                       NaN            NaN  1971.0              Soul  100.0
# 4887                       NaN            NaN  1965.0               Pop  100.0
# 4888                       NaN            NaN  1966.0               Pop  100.0
# 4889                       NaN            NaN  1968.0              Rock  100.0
# 4890                       NaN            NaN  1974.0               Pop  100.0
# 4891                       NaN            NaN  2001.0              Soul   90.0
# 4892                       NaN            NaN  1998.0              Soul  901.0
# 4893                       NaN            NaN  1981.0               Pop   90.0
# 4894                       NaN            NaN  2007.0           Hip-Hop   80.0
# 4895                       NaN            NaN  1994.0              Soul   80.0
# 4896                       NaN            NaN  1995.0         Latin pop   80.0
# 4897                       NaN            NaN  1994.0           Country   80.0
# 4898                       NaN            NaN  1998.0        Electronic   80.0
# 4899                       NaN            NaN  1960.0              Rock   80.0
# 4900                       NaN            NaN  2007.0           Country   75.0
# 4901                       NaN            NaN  1991.0           Hip-Hop   75.0
# 4902                       NaN            NaN  1980.0           Country   75.0
# 4903                       NaN            NaN  1991.0              Soul   75.0
# 4904                       NaN            NaN  1996.0               Pop   75.0
# 4905                       NaN            NaN  1967.0              Rock   75.0
# 4906                       NaN            NaN  1984.0              Jazz   75.0
# 4907                       NaN            NaN  1987.0  New-age / Celtic   75.0
# 4908                       NaN            NaN  1979.0              Rock   75.0
# 4909                       NaN            NaN  1975.0            Reggae   75.0
# 4910                       NaN            NaN  1984.0         Latin pop   75.0
# 4911                       NaN            NaN  1973.0               Pop   75.0

# %%
# Column 'genre'

most_popular_albuns_and_nominated_artists_with_sales.loc[4868:4912,['genre_x']] = most_popular_albuns_and_nominated_artists_with_sales['genre_y'].str.lower()

# %%
# Column 'release_date' --> this column will have the years of release dates from albuns and the reference 
    #year of each artist active period  
most_popular_albuns_and_nominated_artists_with_sales.loc[4868:4912,['release_date']] = most_popular_albuns_and_nominated_artists_with_sales['year']

# %%
most_popular_albuns_and_nominated_artists_with_sales[most_popular_albuns_and_nominated_artists_with_sales['popular_ranking'].\
                                                     isna() == True]
# Out:
#       popular_ranking         artist_name  release_date           genre_x  \
# 4867              NaN        mariah carey           NaN               NaN
# 4868              NaN     whitney houston        1984.0              soul
# 4869              NaN         celine dion        1981.0              rock
# 4870              NaN        garth brooks        1989.0           country
# 4871              NaN    barbra streisand        1963.0               pop
# 4872              NaN         chris brown        2005.0               pop
# 4873              NaN            bee gees        1963.0               pop
# 4874              NaN       george strait        1984.0           country
# 4875              NaN                pink        2000.0               pop
# 4876              NaN                 b'z        1988.0              rock
# 4877              NaN        shania twain        1993.0           country
# 4878              NaN     backstreet boys        1995.0               pop
# 4879              NaN        neil diamond        1966.0               pop
# 4880              NaN             journey        1975.0              rock
# 4881              NaN        kenny rogers        1975.0           country
# 4882              NaN      julio iglesias        1968.0         latin pop
# 4883              NaN           foreigner        1977.0              rock
# 4884              NaN             chicago        1969.0              rock
# 4885              NaN      the carpenters        1969.0               pop
# 4886              NaN  earth, wind & fire        1971.0              soul
# 4887              NaN                cher        1965.0               pop
# 4888              NaN  olivia newton-john        1966.0               pop
# 4889              NaN      linda ronstadt        1968.0              rock
# 4890              NaN        donna summer        1974.0               pop
# 4891              NaN         alicia keys        2001.0              soul
# 4892              NaN  christina aguilera        1998.0              soul
# 4893              NaN       lionel richie        1981.0               pop
# 4894              NaN            flo rida        2007.0           hip-hop
# 4895              NaN               usher        1994.0              soul
# 4896              NaN             shakira        1995.0         latin pop
# 4897              NaN          tim mcgraw        1994.0           country
# 4898              NaN      ayumi hamasaki        1998.0        electronic
# 4899              NaN     johnny hallyday        1960.0              rock
# 4900              NaN          luke bryan        2007.0           country
# 4901              NaN        tupac shakur        1991.0           hip-hop
# 4902              NaN             alabama        1980.0           country
# 4903              NaN            r. kelly        1991.0              soul
# 4904              NaN     robbie williams        1996.0               pop
# 4905              NaN           bob seger        1967.0              rock
# 4906              NaN             kenny g        1984.0              jazz
# 4907              NaN                enya        1987.0  new-age / celtic
# 4908              NaN         bryan adams        1979.0              rock
# 4909              NaN          bob marley        1975.0            reggae
# 4910              NaN      gloria estefan        1984.0         latin pop
# 4911              NaN       barry manilow        1973.0               pop
#
#       total_awards_nominations  uk number 1's    year           genre_y  sales
# 4867                       NaN            NaN  1990.0              Soul  220.0
# 4868                       NaN            NaN  1984.0              Soul  200.0
# 4869                       NaN            NaN  1981.0              Rock  200.0
# 4870                       NaN            NaN  1989.0           Country  170.0
# 4871                       NaN            NaN  1963.0               Pop  150.0
# 4872                       NaN            NaN  2005.0               Pop  140.0
# 4873                       NaN            NaN  1963.0               Pop  120.0
# 4874                       NaN            NaN  1984.0           Country  100.0
# 4875                       NaN            NaN  2000.0               Pop  100.0
# 4876                       NaN            NaN  1988.0              Rock  100.0
# 4877                       NaN            NaN  1993.0           Country  100.0
# 4878                       NaN            NaN  1995.0               Pop  100.0
# 4879                       NaN            NaN  1966.0               Pop  100.0
# 4880                       NaN            NaN  1975.0              Rock  100.0
# 4881                       NaN            NaN  1975.0           Country  100.0
# 4882                       NaN            NaN  1968.0         Latin pop  100.0
# 4883                       NaN            NaN  1977.0              Rock  100.0
# 4884                       NaN            NaN  1969.0              Rock  100.0
# 4885                       NaN            NaN  1969.0               Pop  100.0
# 4886                       NaN            NaN  1971.0              Soul  100.0
# 4887                       NaN            NaN  1965.0               Pop  100.0
# 4888                       NaN            NaN  1966.0               Pop  100.0
# 4889                       NaN            NaN  1968.0              Rock  100.0
# 4890                       NaN            NaN  1974.0               Pop  100.0
# 4891                       NaN            NaN  2001.0              Soul   90.0
# 4892                       NaN            NaN  1998.0              Soul  901.0
# 4893                       NaN            NaN  1981.0               Pop   90.0
# 4894                       NaN            NaN  2007.0           Hip-Hop   80.0
# 4895                       NaN            NaN  1994.0              Soul   80.0
# 4896                       NaN            NaN  1995.0         Latin pop   80.0
# 4897                       NaN            NaN  1994.0           Country   80.0
# 4898                       NaN            NaN  1998.0        Electronic   80.0
# 4899                       NaN            NaN  1960.0              Rock   80.0
# 4900                       NaN            NaN  2007.0           Country   75.0
# 4901                       NaN            NaN  1991.0           Hip-Hop   75.0
# 4902                       NaN            NaN  1980.0           Country   75.0
# 4903                       NaN            NaN  1991.0              Soul   75.0
# 4904                       NaN            NaN  1996.0               Pop   75.0
# 4905                       NaN            NaN  1967.0              Rock   75.0
# 4906                       NaN            NaN  1984.0              Jazz   75.0
# 4907                       NaN            NaN  1987.0  New-age / Celtic   75.0
# 4908                       NaN            NaN  1979.0              Rock   75.0
# 4909                       NaN            NaN  1975.0            Reggae   75.0
# 4910                       NaN            NaN  1984.0         Latin pop   75.0
# 4911                       NaN            NaN  1973.0               Pop   75.0

# %%
# Columns 'total_awards_nominations', "uk number 1's", "popular_ranking" --> for those columns the Nan will be replaced by 0 since
    # some of the artist with most sales don't have nominations or presences on "uk number 1's", neither albuns on the the list of
        #the most popular ones.

most_popular_albuns_and_nominated_artists_with_sales['total_awards_nominations'] = most_popular_albuns_and_nominated_artists_with_sales['total_awards_nominations'].fillna(0)
most_popular_albuns_and_nominated_artists_with_sales["uk number 1's"] = most_popular_albuns_and_nominated_artists_with_sales["uk number 1's"].fillna(0)
most_popular_albuns_and_nominated_artists_with_sales['popular_ranking'] = most_popular_albuns_and_nominated_artists_with_sales['popular_ranking'].fillna(0)

#Column 'Sales' null values will be replaced by 0 since this null's correspond to the artists that have popular albuns, or award nominations
    #but are not in the list of the most profitable musicians

most_popular_albuns_and_nominated_artists_with_sales['sales'] = most_popular_albuns_and_nominated_artists_with_sales['sales']\
.fillna(0)

# %%
most_popular_albuns_and_nominated_artists_with_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4912 entries, 0 to 4911
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   popular_ranking           4912 non-null   float64
#  1   artist_name               4912 non-null   object
#  2   release_date              4911 non-null   float64
#  3   genre_x                   4911 non-null   object
#  4   total_awards_nominations  4912 non-null   float64
#  5   uk number 1's             4912 non-null   float64
#  6   year                      528 non-null    float64
#  7   genre_y                   528 non-null    object
#  8   sales                     4912 non-null   float64
# dtypes: float64(6), object(3)
# memory usage: 512.8+ KB

# %%
most_popular_albuns_and_nominated_artists_with_sales
# Out:
#       popular_ranking     artist_name  release_date           genre_x  \
# 0                 1.0       radiohead        1997.0              rock
# 1                 2.0       radiohead        2000.0              rock
# 2                 6.0       radiohead        2007.0              rock
# 3                 9.0       radiohead        1995.0              rock
# 4                21.0       radiohead        2001.0              rock
# ...               ...             ...           ...               ...
# 4907              0.0            enya        1987.0  new-age / celtic
# 4908              0.0     bryan adams        1979.0              rock
# 4909              0.0      bob marley        1975.0            reggae
# 4910              0.0  gloria estefan        1984.0         latin pop
# 4911              0.0   barry manilow        1973.0               pop
#
#       total_awards_nominations  uk number 1's    year           genre_y  sales
# 0                         18.0            0.0     NaN               NaN    0.0
# 1                         18.0            0.0     NaN               NaN    0.0
# 2                         18.0            0.0     NaN               NaN    0.0
# 3                         18.0            0.0     NaN               NaN    0.0
# 4                         18.0            0.0     NaN               NaN    0.0
# ...                        ...            ...     ...               ...    ...
# 4907                       0.0            0.0  1987.0  New-age / Celtic   75.0
# 4908                       0.0            0.0  1979.0              Rock   75.0
# 4909                       0.0            0.0  1975.0            Reggae   75.0
# 4910                       0.0            0.0  1984.0         Latin pop   75.0
# 4911                       0.0            0.0  1973.0               Pop   75.0
#
# [4912 rows x 9 columns]

# %%
# right now, the columns 'year','genre_y' are no needed

most_popular_albuns_and_nominated_artists_with_sales = most_popular_albuns_and_nominated_artists_with_sales.drop\
(['year','genre_y'],axis = 1)

# %%
most_popular_albuns_and_nominated_artists_with_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4912 entries, 0 to 4911
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   popular_ranking           4912 non-null   float64
#  1   artist_name               4912 non-null   object
#  2   release_date              4911 non-null   float64
#  3   genre_x                   4911 non-null   object
#  4   total_awards_nominations  4912 non-null   float64
#  5   uk number 1's             4912 non-null   float64
#  6   sales                     4912 non-null   float64
# dtypes: float64(5), object(2)
# memory usage: 436.0+ KB

# %%
most_popular_albuns_and_nominated_artists_with_sales[most_popular_albuns_and_nominated_artists_with_sales['release_date'].isna() == True]

most_popular_albuns_and_nominated_artists_with_sales['release_date']= most_popular_albuns_and_nominated_artists_with_sales\
['release_date'].fillna(1990)

most_popular_albuns_and_nominated_artists_with_sales['genre_x']= most_popular_albuns_and_nominated_artists_with_sales\
['genre_x'].fillna('pop')

# %%
# Finally, for the exploratory analisis of this data fram, the column names need to be update so that can be more clear about 
    #their meaning

most_popular_albuns_and_nominated_artists_with_sales = most_popular_albuns_and_nominated_artists_with_sales.rename\
(columns={'popular_ranking':'popular_albuns_rank', 'artist_name':'artist_band', 'genre_x':'musical_genre', 'sales':'million_sales','release_date':'reference_year'})

# %%
most_popular_albuns_and_nominated_artists_with_sales['reference_year'] = most_popular_albuns_and_nominated_artists_with_sales\
['reference_year'].apply(lambda x: int(x))

most_popular_albuns_and_nominated_artists_with_sales['popular_albuns_rank'] = most_popular_albuns_and_nominated_artists_with_sales\
['popular_albuns_rank'].apply(lambda x: int(x))

most_popular_albuns_and_nominated_artists_with_sales['total_awards_nominations'] = most_popular_albuns_and_nominated_artists_with_sales\
['total_awards_nominations'].apply(lambda x: int(x))

most_popular_albuns_and_nominated_artists_with_sales["uk number 1's"] = most_popular_albuns_and_nominated_artists_with_sales\
["uk number 1's"].apply(lambda x: int(x))

most_popular_albuns_and_nominated_artists_with_sales["million_sales"] = most_popular_albuns_and_nominated_artists_with_sales\
["million_sales"].apply(lambda x: int(x))

# %%
most_popular_albuns_and_nominated_artists_with_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4912 entries, 0 to 4911
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   popular_albuns_rank       4912 non-null   int64
#  1   artist_band               4912 non-null   object
#  2   reference_year            4912 non-null   int64
#  3   musical_genre             4912 non-null   object
#  4   total_awards_nominations  4912 non-null   int64
#  5   uk number 1's             4912 non-null   int64
#  6   million_sales             4912 non-null   int64
# dtypes: int64(5), object(2)
# memory usage: 436.0+ KB

# %%
most_popular_albuns_and_nominated_artists_with_sales
# Out:
#       popular_albuns_rank     artist_band  reference_year     musical_genre  \
# 0                       1       radiohead            1997              rock
# 1                       2       radiohead            2000              rock
# 2                       6       radiohead            2007              rock
# 3                       9       radiohead            1995              rock
# 4                      21       radiohead            2001              rock
# ...                   ...             ...             ...               ...
# 4907                    0            enya            1987  new-age / celtic
# 4908                    0     bryan adams            1979              rock
# 4909                    0      bob marley            1975            reggae
# 4910                    0  gloria estefan            1984         latin pop
# 4911                    0   barry manilow            1973               pop
#
#       total_awards_nominations  uk number 1's  million_sales
# 0                           18              0              0
# 1                           18              0              0
# 2                           18              0              0
# 3                           18              0              0
# 4                           18              0              0
# ...                        ...            ...            ...
# 4907                         0              0             75
# 4908                         0              0             75
# 4909                         0              0             75
# 4910                         0              0             75
# 4911                         0              0             75
#
# [4912 rows x 7 columns]

# %%
most_popular_albuns_and_nominated_artists_with_sales.to_csv('../../Data/cleaned_data/merged_data/most_popular_albuns_and_nominated_artists_with_sales.csv', index=False)

# %%
#IMPORTANT NOTE: Afterwards was decided to use this version on the 
    #merging of df1 and df2 since in this version we have more data because we
    # use the column 'total nominations' instead of grammy_awards and grammy_nominations
    # we also wanto to use the column 'UK_number 1's' since this reflects the
    #preference of the public

# %%
import pandas as pd

# %%
df2 = pd.read_csv('../../../Data/raw_data/2. greatest_artists_grammys_billboard.csv')
df2
# Out:
#     Rolling Stone Magazine Rank                       Artist  \
# 0                             1                  The Beatles
# 1                             2                    Bob Dylan
# 2                             3                Elvis Presley
# 3                             4           The Rolling Stones
# 4                             5                  Chuck Berry
# ..                          ...                          ...
# 95                           96  Diana Ross and the Supremes
# 96                           97                       R.E.M.
# 97                           98              Curtis Mayfield
# 98                           99                 Carl Perkins
# 99                          100                Talking Heads
#
#    Racial/Ethnic group  Main Grammy awards  Main Grammy Nominations  \
# 0       White/European                   2                       10
# 1       White/European                   1                        4
# ...

# %%
df2.columns
# Out:
# Index(['Rolling Stone Magazine Rank', 'Artist', 'Racial/Ethnic group',
#        'Main Grammy awards', 'Main Grammy Nominations', 'Total Awards',
#        'Total Nominations', 'UK number 1's'],
#       dtype='object')

# %%
df2[df2['Artist']=='Little Richard']
# Out:
#    Rolling Stone Magazine Rank          Artist Racial/Ethnic group  \
# 7                            8  Little Richard       Black/African
#
#    Main Grammy awards  Main Grammy Nominations  Total Awards  \
# 7                   0                        0             0
#
#    Total Nominations  UK number 1's
# 7                  0              0

# %%
# Columns to drop since they are no needed

df2 = df2.drop(['Rolling Stone Magazine Rank', 'Racial/Ethnic group','Total Awards'], axis = 1)
df2
# Out:
#                          Artist  Main Grammy awards  Main Grammy Nominations  \
# 0                   The Beatles                   2                       10
# 1                     Bob Dylan                   1                        4
# 2                 Elvis Presley                   0                        2
# 3            The Rolling Stones                   0                        1
# 4                   Chuck Berry                   0                        0
# ..                          ...                 ...                      ...
# 95  Diana Ross and the Supremes                   0                        0
# 96                       R.E.M.                   0                        3
# 97              Curtis Mayfield                   0                        0
# 98                 Carl Perkins                   0                        0
# 99                Talking Heads                   0                        0
#
#     Total Nominations  UK number 1's
# ...

# %%
df2.columns
# Out:
# Index(['Artist', 'Main Grammy awards', 'Main Grammy Nominations',
#        'Total Nominations', 'UK number 1's'],
#       dtype='object')

# %%
#Normalizing columns names

cols = []
for column in df2.columns:
    cols.append(column.lower())
df2.columns = cols
df2.columns


#renaming columns so they can be normalized with df1 (other Notebook) 

df2 = df2.rename(columns = {'artist':'artist_name', 'main grammy awards':'main_grammy_awards', 
                            'main grammy nominations':'main_grammy_nominations', 'total nominations':'total_awards_nominations'})
df2.columns
# Out:
# Index(['artist_name', 'main_grammy_awards', 'main_grammy_nominations',
#        'total_awards_nominations', 'uk number 1's'],
#       dtype='object')

# %%
df2.info() #--> No null cells in all the columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   artist_name               100 non-null    object
#  1   main_grammy_awards        100 non-null    int64
#  2   main_grammy_nominations   100 non-null    int64
#  3   total_awards_nominations  100 non-null    int64
#  4   uk number 1's             100 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 4.0+ KB

# %%
df2['artist_name'] = df2['artist_name'].str.lower() #Lower all cells in artist_name
df2
# Out:
#                     artist_name  main_grammy_awards  main_grammy_nominations  \
# 0                   the beatles                   2                       10
# 1                     bob dylan                   1                        4
# 2                 elvis presley                   0                        2
# 3            the rolling stones                   0                        1
# 4                   chuck berry                   0                        0
# ..                          ...                 ...                      ...
# 95  diana ross and the supremes                   0                        0
# 96                       r.e.m.                   0                        3
# 97              curtis mayfield                   0                        0
# 98                 carl perkins                   0                        0
# 99                talking heads                   0                        0
#
#     total_awards_nominations  uk number 1's
# ...

# %%
df2[df2['artist_name']=='chuck berry']
# Out:
#    artist_name  main_grammy_awards  main_grammy_nominations  \
# 4  chuck berry                   0                        0
#
#    total_awards_nominations  uk number 1's
# 4                         0              1

# %%
df2[df2['artist_name']=='lynyrd_skynyrd']
# Out:
# Empty DataFrame
# Columns: [artist_name, main_grammy_awards, main_grammy_nominations, total_awards_nominations, uk number 1's]
# Index: []

# %%
df2 = df2.drop(['main_grammy_awards', 'main_grammy_nominations'],axis = 1)

# %%
df2
# Out:
#                     artist_name  total_awards_nominations  uk number 1's
# 0                   the beatles                        29             17
# 1                     bob dylan                        38              1
# 2                 elvis presley                         4             21
# 3            the rolling stones                        14              8
# 4                   chuck berry                         0              1
# ..                          ...                       ...            ...
# 95  diana ross and the supremes                         2              1
# 96                       r.e.m.                        13              0
# 97              curtis mayfield                         8              0
# 98                 carl perkins                         2              0
# 99                talking heads                         2              0
#
# [100 rows x 3 columns]

# %%
#filter1 = df2[(df2['total_awards_nominations']==0) & (df2["uk number 1's"]==0)]
filter1 = df2[(df2['total_awards_nominations']!=0) | (df2["uk number 1's"]!=0)]

# There still are artists with total_awards_nominations+uk number 1' = 0

    # this are the artists that also are ranken on rolling stone ranking
    # We'll not use this column to answer our project goals since it can be
    # too much parameters to evalueate the genre popularity 
    #THEREFORE this values gonn be dropped out.

# %%
df2 = filter1

# %%
df2
# Out:
#                     artist_name  total_awards_nominations  uk number 1's
# 0                   the beatles                        29             17
# 1                     bob dylan                        38              1
# 2                 elvis presley                         4             21
# 3            the rolling stones                        14              8
# 4                   chuck berry                         0              1
# ..                          ...                       ...            ...
# 95  diana ross and the supremes                         2              1
# 96                       r.e.m.                        13              0
# 97              curtis mayfield                         8              0
# 98                 carl perkins                         2              0
# 99                talking heads                         2              0
#
# [83 rows x 3 columns]

# %%
#df2[df2['artist_name']=='carlos santana']

def santana(x):
    if ('carlos santana' in x):
        return 'santana'
    else:
        return x
    

df2['artist_name'] = df2['artist_name'].apply(santana)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12012\1862286455.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['artist_name'] = df2['artist_name'].apply(santana)

# %%
df2[df2['artist_name']=='santana']
# Out:
#    artist_name  total_awards_nominations  uk number 1's
# 89     santana                        14              0

# %%
df2[df2['genre']=='soul_funk']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\Ironhack\Week_5\Mid_bootcamp_project\venv\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\Documents\Ironhack\Week_5\Mid_bootcamp_project\venv\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Documents\Ironhack\Week_5\Mid_bootcamp_project\venv\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'genre'
#
# ...

# %%
df2.to_csv('../../../Data/cleaned_data/2. greatest_artists_grammys_billboard_version3_CLEANED_.csv', index = False)

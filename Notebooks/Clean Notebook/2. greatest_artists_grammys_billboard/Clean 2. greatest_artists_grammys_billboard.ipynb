# %%
import pandas as pd

# %%
df2 = pd.read_csv('../../../Data/raw_data/2. greatest_artists_grammys_billboard.csv')
df2
# Out:
#     Rolling Stone Magazine Rank                       Artist  \
# 0                             1                  The Beatles
# 1                             2                    Bob Dylan
# 2                             3                Elvis Presley
# 3                             4           The Rolling Stones
# 4                             5                  Chuck Berry
# ..                          ...                          ...
# 95                           96  Diana Ross and the Supremes
# 96                           97                       R.E.M.
# 97                           98              Curtis Mayfield
# 98                           99                 Carl Perkins
# 99                          100                Talking Heads
#
#    Racial/Ethnic group  Main Grammy awards  Main Grammy Nominations  \
# 0       White/European                   2                       10
# 1       White/European                   1                        4
# ...

# %%
#what is possible to gather from this data set ?
    # Genres with more grammys --> have to relation this with data frame 1 because here we do not have a column genre. so the name of the artist have to be normalized with data set 1 before concatenating
    # Genres with more grammy nomiations --> The agrregation of genres it only can be done after de cleaning and the concatenating with data set 1
    
    #here we only see at the grammys awards/nominations since it is one of the most important and old award in music since 1959

# %%
df2[df2['Artist']== 'Kanye West']
# Out:
# Empty DataFrame
# Columns: [Rolling Stone Magazine Rank, Artist, Racial/Ethnic group, Main Grammy awards, Main Grammy Nominations, Total Awards, Total Nominations, UK number 1's]
# Index: []

# %%
df2.columns

# %%
# Columns to drop since they are no needed

df2 = df2.drop(['Rolling Stone Magazine Rank', 'Racial/Ethnic group','Total Nominations', "UK number 1's",'Total Awards'], axis = 1)
df2

# %%
#Normalizing columns names

cols = []
for column in df2.columns:
    cols.append(column.lower())
df2.columns = cols
df2.columns

#renaming columns so they can be normalized with df1 (other Notebook) 

df2 = df2.rename(columns = {'artist':'artist_name', 'main grammy awards':'main_grammy_awards', 
                            'main grammy nominations':'main_grammy_nominations'})
df2

# %%
df2.info() #--> No null cells in all the columns

# %%
df2['artist_name'] = df2['artist_name'].str.lower() #Lower all cells in artist_name
df2

# %%
df2[(df2['main_grammy_awards']==0) &(df2['main_grammy_nominations']!=0)]

# %%
#df2.to_csv('../../../Data/cleaned_data/2. greatest_artists_grammys_billboard_CLEANED.csv', index = False)

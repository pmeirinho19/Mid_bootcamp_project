# %%
import pandas as pd

# %%
pd.read_csv('2. greatest_artists_grammys_billboard.csv')
# Out:
#     Rolling Stone Magazine Rank                       Artist  \
# 0                             1                  The Beatles
# 1                             2                    Bob Dylan
# 2                             3                Elvis Presley
# 3                             4           The Rolling Stones
# 4                             5                  Chuck Berry
# ..                          ...                          ...
# 95                           96  Diana Ross and the Supremes
# 96                           97                       R.E.M.
# 97                           98              Curtis Mayfield
# 98                           99                 Carl Perkins
# 99                          100                Talking Heads
#
#    Racial/Ethnic group  Main Grammy awards  Main Grammy Nominations  \
# 0       White/European                   2                       10
# 1       White/European                   1                        4
# ...

# %%
#what is possible to gather from this data set ?
    # Genres with more grammys --> have to relation this with data frame 1 because here we do not have a column genre. so the name of the artist have to be normalized with data set 1
    #Genres with more nomiations --> The agrregation of genres it only can be done after de cleaning and the concatenating with data set 1
    #here we are limited due the starting year of grammys awards 1959

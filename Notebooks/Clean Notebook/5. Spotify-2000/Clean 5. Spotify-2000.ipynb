# %%
import pandas as pd

# %%
#what is possible to gather from this data set ?
 #what is possible to gather from this data set ?
    # Most rentable = most popular genres of music
    # Most popular countrys for music
    # normalize years or add new column to what year each artist belong
    
    #NOTE: this list have a lot of missing values. Also the to gather the information that i want is need a lot of work that i mabye won't have. Thus i can gahter the same information by the data set 4

# %%
pd.read_csv('5. Spotify-2000.csv').head(50)
# Out:
#     Index                                      Title              Artist  \
# 0       1                                    Sunrise         Norah Jones
# 1       2                                Black Night         Deep Purple
# 2       3                             Clint Eastwood            Gorillaz
# 3       4                              The Pretender        Foo Fighters
# 4       5                     Waitin' On A Sunny Day   Bruce Springsteen
# 5       6      The Road Ahead (Miles Of The Unknown)        City To City
# 6       7                          She Will Be Loved            Maroon 5
# 7       8                         Knights of Cydonia                Muse
# 8       9                             Mr. Brightside         The Killers
# 9      10                                 Without Me              Eminem
# 10     11                             Love Me Tender       Elvis Presley
# 11     12                          Seven Nation Army   The White Stripes
# ...

# %%
#what is possible to gather from this data set ?
    # top songs (most played songs) on spotify for decade until 2000 (interval that i'm interested in here)
    # get the most popular genres in all decades to compare with data sets that are not using spotify datas
    # need to normalize the genres names and also the artist names to concatenate with other data sets?
    # get agreggations by year ?

# %%
import pandas as pd

# %%
df4 = pd.read_csv('../../../Data/raw_data/4. best_selling_artists_of_all_time.csv') 
df4
# Out:
#               Artist         Country       period_active  Year  \
# 0        The Beatles  United Kingdom           1960–1970  1962
# 1      Elvis Presley   United States           1954–1977  1956
# 2    Michael Jackson   United States           1964–2009  1971
# 3         Elton John  United Kingdom        1964–present  1970
# 4              Queen  United Kingdom        1971–present  1973
# ..               ...             ...                 ...   ...
# 116       The Police  United Kingdom  1977–19862007–2008  1978
# 117   Gloria Estefan   United States        1975–present  1984
# 118    Barry Manilow   United States        1973–present  1973
# 119             Kiss   United States        1972–present  1974
# 120  Aretha Franklin   United States           1956–2018  1961
#
#                                Genre            TCU                   Sales
# 0                         Rock / pop  290.4 million  600 million500 million
# ...

# %%
#what is possible to gather from this data set ?
    # Most rentable = most popular genres of music
    # Most popular countrys for music
    # normalize years or add new column to what year each artist belong

# %%
df4 = df4.drop(['TCU', 'period_active'], axis = 1) # Columns that are no needed. We drop period_active because we have
        #column 'Year' that refers to the first year that the artist had his firts songs on charts. For future reference we assume
        #that this here is corresponding to the time when the artist was most profitable.

# %%
df4 = df4.rename(columns = {'Artist' : 
                            'artist_name', 'Country':'country', 'Year' : 'year', 'Genre':'genre','Sales':'sales'})

# %%
df4.head(60)
# Out:
#               artist_name                             country  year  \
# 0             The Beatles                      United Kingdom  1962
# 1           Elvis Presley                       United States  1956
# 2         Michael Jackson                       United States  1971
# 3              Elton John                      United Kingdom  1970
# 4                   Queen                      United Kingdom  1973
# 5                 Madonna                       United States  1983
# 6            Led Zeppelin                      United Kingdom  1969
# 7                 Rihanna                            Barbados  2005
# 8              Pink Floyd                      United Kingdom  1967
# 9                  Eminem                       United States  1999
# 10           Mariah Carey                       United States  1990
# 11           Taylor Swift                       United States  2006
# 12                Beyoncé                       United States  2002
# ...

# %%
df4['artist_name'] = df4['artist_name'].str.lower() # To turn all the strings lower as was made in the other data frames
df4['country'] = df4['country'].str.lower()

# %%
import time
from datetime import date

def transform_to_date(x):
    x = pd.to_datetime(x, errors='coerce', format='%Y')
    return x.year

df4['year'] = df4['year'].apply(transform_to_date)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   artist_name  121 non-null    object
#  1   country      121 non-null    object
#  2   year         121 non-null    int64
#  3   genre        121 non-null    object
#  4   sales        121 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.9+ KB

# %%
df4['genre'].value_counts().head(60)
# Out:
# Rock                                         9
# Rock / pop                                   7
# Pop                                          5
# Hip-hop                                      4
# Pop / rock                                   4
# Hard rock / heavy metal                      4
# R&B / pop                                    3
# Pop / R&B                                    3
# Country                                      3
# Hip-hop / R&B / pop                          2
# Funk / R&B / soul                            2
# Rock / hard rock                             2
# Pop / R&B / hip-hop                          2
# Pop / disco                                  2
# R&B / pop / rock                             1
# Pop / disco / R&B                            1
# Country / rock and roll / gospel             1
# Progressive rock / pop rock                  1
# Rock / pop / surf rock                       1
# Rock / folk / country                        1
# ...

# %%
def normalize_genres2(x):
    if ('Rock' in x):
        x=x.replace(x,'Rock')
        return x
    if ('Krautrock' in x):
        x=x.replace(x,'Rock')
        return x
    if ('Punk' in x):
        x=x.replace(x,'Rock')
        return x
    if ('Post-Hardcore' in x):
        x=x.replace(x,'Rock')
        return x
    if ('Midwest Emo' in x):
        x=x.replace(x,'Rock')
        return x
    if ('Slowcore' in x):
        x=x.replace(x,'Rock')
        return x
    if ('Britpop' in x):
        x=x.replace(x,'Rock')
        return x
    if ('Neo-Psychedelia' in x):
        x=x.replace(x,'Rock')
        return x
    if ('Shoegaze' in x):
        x=x.replace(x,'Rock')
        return x
    if ('Grunge' in x):
        x=x.replace(x,'Rock')
        return x
    if ('Neo-Prog' in x):
        x=x.replace(x,'Rock')
        return x
    if ("Baggy/Madchester" in x):
        x=x.replace(x,'Rock')
        return x
    if ('Heavy Psych' in x):
        x=x.replace(x,'Rock')
        return x
    if ('Emo' in x):
        x=x.replace(x,'Rock')
        return x
    if ('Emoviolence' in x):
        x=x.replace(x,'Rock')
        return x
    if ('Latin Alternative' in x):
        x=x.replace(x,'Rock')
        return x
    if ('Symphonic Prog' in x):
        x=x.replace(x,'Rock')
        return x
    if ('Riot Grrrl' in x):
        x=x.replace(x,'Rock')
        return x
    if ('AOR' in x):
        x=x.replace(x,'Rock')
        return x
    if ('Hard rock' in x):
        x=x.replace(x,'Rock')
        return x
    if ('Alternative rock' in x):
        x=x.replace(x,'Rock')
        return x
    if ('Art rock' in x):
        x=x.replace(x,'Rock')
        return x
    if ('Progressive rock' in x):
        x=x.replace(x,'Rock')
        return x
    if ('Psychedelic rock' in x):
        x=x.replace(x,'Rock')
        return x
    if ('Metal' in x):
        x=x.replace(x,'Metal')
        return x
    if ('Grindcore' in x):
        x=x.replace(x,'Metal')
        return x
    if ('Mathcore' in x):
        x=x.replace(x,'Metal')
        return x
    if ('Djent' in x):
        x=x.replace(x,'Metal')
        return x
    if ('Deathgrind' in x):
        x=x.replace(x,'Metal')
        return x
    if ("Death'n'Roll" in x):
        x=x.replace(x,'Metal')
        return x
    if ("Neue Deutsche Härte" in x):
        x=x.replace(x,'Metal')
        return x
    if ("Screamo" in x):
        x=x.replace(x,'Metal')
        return x
    if ("Crossover Thrash" in x):
        x=x.replace(x,'Metal')
        return x
    if ("metal" in x):
        x=x.replace(x,'Metal')
        return x
    if ("Deathcore" in x):
        x=x.replace(x,'Metal')
        return x
    if ('Pop' in x):
        x=x.replace(x,'Pop')
        return x
    if ('The Black Eyed Peas' in x):
        x=x.replace(x,'Pop')
        return x
    if ('R.Kelly' in x):
        x=x.replace(x,'Pop')
        return x
    if ('Blues' in x):
        x=x.replace(x,'Blues')
        return x
    if ('Folk' in x):
        x=x.replace(x,'Folk')
        return x
    if ('American Primitivism' in x):
        x=x.replace(x,'Folk')
        return x
    if ('Neofolk' in x):
        x=x.replace(x,'Folk')
        return x
    if ('Nuevacanciónlatinoamericana' in x):
        x=x.replace(x,'Folk')
        return x
    if ('Soul' in x):
        x=x.replace(x,'Soul_Funk')
        return x
    if ('R&B' in x):
        x=x.replace(x,'Pop')
        return x
    if ('Earth, Wind & Fire' in x):
        x=x.replace(x,'Soul_Funk')
        return x
    if ('Aretha Franklin' in x):
        x=x.replace(x,'Soul_Funk')
        return x
    if ('Stevie Wonder' in x):
        x=x.replace(x,'Soul_Funk')
        return x
    if ('Jazz' in x):
        x=x.replace(x,'Jazz')
        return x
    if ('Post-Bop' in x):
        x=x.replace(x,'Jazz')
        return x
    if ('Hard-Bop' in x):
        x=x.replace(x,'Jazz')
        return x
    if ('Hard Bop' in x):
        x=x.replace(x,'Jazz')
        return x
    if ('Bossanova' in x):
        x=x.replace(x,'Jazz')
        return x
    if ('jazz' in x):
        x=x.replace(x,'Jazz')
        return x
    if ('Hip-Hop' in x):
        x=x.replace(x,'Hip-Hop')
        return x
    if ('Hip Hop' in x):
        x=x.replace(x,'Hip-Hop')
        return x
    if ('Hip hop' in x):
        x=x.replace(x,'Hip-Hop')
        return x
    if ('Hip-hop' in x):
        x=x.replace(x,'Hip-Hop')
        return x
    if ('Gangsta Rap' in x):
        x=x.replace(x,'Hip-Hop')
        return x
    if ('Rap' in x):
        x=x.replace(x,'Hip-Hop')
        return x
    if ('Eminem' in x):
        x=x.replace(x,'Hip-Hop')
        return x
    if ('Jay-Z' in x):
        x=x.replace(x,'Hip-Hop')
        return x
    if ('Lil Wayne' in x):
        x=x.replace(x,'Hip-Hop')
        return x
    if ('Tupac Shakur' in x):
        x=x.replace(x,'Hip-Hop')
        return x
    if ('Flo Rida' in x):
        x=x.replace(x,'Hip-Hop')
        return x
    if ('Rap' in x):
        x=x.replace(x,'Hip-Hop')
        return x
    if ('Vaportrap' in x):
        x=x.replace(x,'Hip-Hop')
        return x
    if ('Trap' in x):
        x=x.replace(x,'Hip-Hop')
        return x
    if ('Funk' in x):
        x=x.replace(x,'Soul_Funk')
        return x
    if ('Americana, Country' in x):
        x=x.replace(x,'Country')
        return x
    if ("Alt-Country" in x):
        x=x.replace(x,'Country')
        return x
    if ("Outlaw Country" in x):
        x=x.replace(x,'Country')
        return x
    if ("Garth Brooks" in x):
        x=x.replace(x,'Country')
        return x
    if ("George Strait" in x):
        x=x.replace(x,'Country')
        return x
    if ("Tim Mcgraw" in x):
        x=x.replace(x,'Country')
        return x
    if ("Country" in x):
        x=x.replace(x,'Country')
        return x
    if ('Reggae' in x):
        x=x.replace(x,'Reggae')
        return x
    if ('Synthpop' in x):
        x=x.replace(x,'Electronic')
        return x
    if ('Electropop' in x):
        x=x.replace(x,'Electronic')
        return x
    if ('IDM' in x):
        x=x.replace(x,'Electronic')
        return x
    if ('Progressive Electronic' in x):
        x=x.replace(x,'Electronic')
        return x
    if ('Electronic' in x):
        x=x.replace(x,'Electronic')
        return x
    if ('Ambient' in x):
        x=x.replace(x,'Electronic')
        return x
    if ('Industrial' in x):
        x=x.replace(x,'Electronic')
        return x
    if ('Big Beat' in x):
        x=x.replace(x,'Electronic')
        return x
    if ('Downtempo' in x):
        x=x.replace(x,'Electronic')
        return x
    if ('Digital Hardcore' in x):
        x=x.replace(x,'Electronic')
        return x
    if ('Electro-Industrial' in x):
        x=x.replace(x,'Electronic')
        return x
    if ('Techno' in x):
        x=x.replace(x,'Electronic')
        return x
    if ('Electro-Industrial' in x):
        x=x.replace(x,'Electronic')
        return x
    if ('Glitch' in x):
        x=x.replace(x,'Electronic')
        return x
    if ('Deep House' in x):
        x=x.replace(x,'Electronic')
        return x
    if ("Microhouse" in x):
        x=x.replace(x,'Electronic')
        return x
    if ("Atmospheric Drumand Bass" in x):
        x=x.replace(x,'Electronic')
        return x
    if ("Chillwave" in x):
        x=x.replace(x,'Electronic')
        return x
    if ("Berlin School" in x):
        x=x.replace(x,'Electronic')
        return x
    if ("Vaporwave" in x):
        x=x.replace(x,'Electronic')
        return x
    if ("Deconstructed Club" in x):
        x=x.replace(x,'Electronic')
        return x
    if ("Future Garage" in x):
        x=x.replace(x,'Electronic')
        return x
    if ("Indietronica" in x):
        x=x.replace(x,'Electronic')
        return x
    if ("Dungeon Synth" in x):
        x=x.replace(x,'Electronic')
        return x
    if ("French House" in x):
        x=x.replace(x,'Electronic')
        return x
    if ("UKBass" in x):
        x=x.replace(x,'Electronic')
        return x
    if ("Wonky" in x):
        x=x.replace(x,'Electronic')
        return x
    if ("Minimal Synth" in x):
        x=x.replace(x,'Electronic')
        return x
    if ("Progressive House" in x):
        x=x.replace(x,'Electronic')
        return x
    if ("Electro-Disco" in x):
        x=x.replace(x,'Electronic')
        return x
    if ("Outsider House" in x):
        x=x.replace(x,'Electronic')
        return x
    if ("Drilland Bass" in x):
        x=x.replace(x,'Electronic')
        return x
    if ("Acid House" in x):
        x=x.replace(x,'Electronic')
        return x
    if ("J-pop" in x):
        x=x.replace(x,'Electronic')
        return x
    if ("Latin pop" in x):
        x=x.replace(x,'Latin pop')
        return x
    if ("Latin" in x):
        x=x.replace(x,'Latin pop')
        return x
    else:
        return x
    

df4['genre'] = df4['genre'].apply(normalize_genres2)
df4['genre'].value_counts()
#df4['genre'] = df4['genre'].str.lower() # we also want to lower the strings
#df4
# Out:
# Pop                 49
# Rock                45
# Country              8
# Hip-Hop              7
# Latin pop            3
# Soul_Funk            2
# Folk                 2
# Metal                1
# Electronic           1
# Jazz                 1
# New-age / Celtic     1
# Reggae               1
# Name: genre, dtype: int64

# %%
#cleaning 'sales'
df4['sales'].value_counts().head(40)

def first_3_digits(x):
    x = x.replace('–','')
    x = x[0:3]       
    return x
 #so we can get the first 3 digits, since the greater number is 600 million, and also to get rid
    # of 'million and the other lower numbers in the cell that represent an interval'
df4['sales'] = df4['sales'].apply(first_3_digits)

# %%
#cleaning 'country' column

df4['country'].value_counts()

def clean_country(x):
    if ('united states' in x):
        return 'united states'
    if ('united kingdom' in x):
        return 'united kingdom'
    if ('canada' in x):
        return 'canada'
    else:
        return x
    
df4['country'] = df4['country'].apply(clean_country)

df4['country'].value_counts()
# Out:
# united states          82
# united kingdom         21
# canada                  5
# australia               2
# ireland                 2
# japan                   2
# barbados                1
# sweden                  1
# trinidad and tobago     1
# spain                   1
# colombia                1
# france                  1
# jamaica                 1
# Name: country, dtype: int64

# %%
df4['genre'] = df4['genre'].str.lower()

# %%
df4[df4['genre']=='soul_funk']
# Out:
#                artist_name        country  year      genre sales
# 40   red hot chili peppers  united states  1987  soul_funk   120
# 120        aretha franklin  united states  1961  soul_funk   75

# %%
df4.to_csv('../../../Data/cleaned_data/4. best_selling_artists_of_all_time[CLEANED].csv', index = False)
